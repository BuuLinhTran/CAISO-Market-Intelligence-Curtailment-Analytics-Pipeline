# %% [markdown]
# # **CAISO Market Intelligence & Curtailment Analytics Pipeline**

# %% [markdown]
# ## SUMMARY

# %% [markdown]
# Developed an end-to-end Python pipeline to monitor grid health and pricing dynamics within the CAISO market. By automating data extraction from CAISO OASIS, the project analyzes Locational Marginal Prices (LMP) and renewable curtailment trends to identify regional oversupply and transmission bottlenecks. Built localized trend models for ZP26, NP15, and SP15 hubs to visualize price divergence and basis risk

# %% [markdown]
# - Miniconda version 26.1.1
# - Python version 3.11.15
# - Pandas v2.3.3
# - Numpy v2.2.5
# - gridstatus v0.35.0

# %%
import pandas as pd
import gridstatus
import plotly.express as px
import kaleido

# %%
print(pd.__version__)
print(gridstatus.__version__)
# Out:
# 2.3.3
# 0.35.0

# %% [markdown]
# ## MAIN ANALYSIS

# %%
iso = gridstatus.CAISO()
# autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Local Marginal Price for Main Trading Hubs

# %% [markdown]
# - https://oasis.caiso.com/mrioasis/logon.do
# - https://bpmcm.caiso.com/BPM%20Document%20Library/Market%20Instruments/BPM_for_Market%20Instruments_V92_Redline.pdf
# Report definition:
# - Aggregated Pricing Nodes (APND)
# - Trading hub codes: NP15 (North of Path 15), ZP26 (Zone Path 26), SP15(South of Path 15)

# %%
start = pd.Timestamp("April 10, 2025").normalize()
end = pd.Timestamp.now().normalize()

locations = ["TH_NP15_GEN-APND", "TH_SP15_GEN-APND", "TH_ZP26_GEN-APND"]

lmp_df = iso.get_lmp(
    start=start, 
    end=end, 
    market="DAY_AHEAD_HOURLY", 
    locations=locations, 
    # sleep=5 # rate limit 5 second for each call//OFF TO REDUCE SPACE
)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]2026-04-14 21:21:52 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:21:52 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20250410T07:00-0000&enddatetime=20250511T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:22:01 - DEBUG - Found 1 files: ['20250410_20250511_PRC_LMP_DAM_20260414_18_21_51_v12.csv']
# 2026-04-14 21:22:01 - DEBUG - Parsing file: 20250410_20250511_PRC_LMP_DAM_20260414_18_21_51_v12.csv
#   8%|▊         | 1/12 [00:13<02:29, 13.62s/it]2026-04-14 21:22:06 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:22:06 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20250511T07:00-0000&enddatetime=20250611T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:22:14 - DEBUG - Found 1 files: ['20250511_20250611_PRC_LMP_DAM_20260414_18_22_05_v12.csv']
# 2026-04-14 21:22:14 - DEBUG - Parsing file: 20250511_20250611_PRC_LMP_DAM_20260414_18_22_05_v12.csv
#  17%|█▋        | 2/12 [00:27<02:14, 13.50s/it]2026-04-14 21:22:19 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:22:19 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20250611T07:00-0000&enddatetime=20250712T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:22:27 - DEBUG - Found 1 files: ['20250611_20250712_PRC_LMP_DAM_20260414_18_22_18_v12.csv']
# 2026-04-14 21:22:27 - DEBUG - Parsing file: 20250611_20250712_PRC_LMP_DAM_20260414_18_22_18_v12.csv
#  25%|██▌       | 3/12 [00:40<02:01, 13.50s/it]2026-04-14 21:22:33 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:22:33 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20250712T07:00-0000&enddatetime=20250812T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:22:41 - DEBUG - Found 1 files: ['20250712_20250812_PRC_LMP_DAM_20260414_18_22_31_v12.csv']
# 2026-04-14 21:22:41 - DEBUG - Parsing file: 20250712_20250812_PRC_LMP_DAM_20260414_18_22_31_v12.csv
#  33%|███▎      | 4/12 [00:53<01:47, 13.47s/it]2026-04-14 21:22:46 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:22:46 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20250812T07:00-0000&enddatetime=20250912T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:22:54 - DEBUG - Found 1 files: ['20250812_20250912_PRC_LMP_DAM_20260414_18_22_44_v12.csv']
# 2026-04-14 21:22:54 - DEBUG - Parsing file: 20250812_20250912_PRC_LMP_DAM_20260414_18_22_44_v12.csv
#  42%|████▏     | 5/12 [01:07<01:34, 13.44s/it]2026-04-14 21:22:59 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:22:59 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20250912T07:00-0000&enddatetime=20251013T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:08 - DEBUG - Found 1 files: ['20250912_20251013_PRC_LMP_DAM_20260414_18_22_58_v12.csv']
# 2026-04-14 21:23:08 - DEBUG - Parsing file: 20250912_20251013_PRC_LMP_DAM_20260414_18_22_58_v12.csv
#  50%|█████     | 6/12 [01:20<01:20, 13.43s/it]2026-04-14 21:23:13 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:23:13 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20251013T07:00-0000&enddatetime=20251113T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:21 - DEBUG - Found 1 files: ['20251013_20251112_PRC_LMP_DAM_20260414_18_23_11_v12.csv']
# 2026-04-14 21:23:21 - DEBUG - Parsing file: 20251013_20251112_PRC_LMP_DAM_20260414_18_23_11_v12.csv
#  58%|█████▊    | 7/12 [01:33<01:06, 13.22s/it]2026-04-14 21:23:26 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:23:26 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20251113T07:00-0000&enddatetime=20251214T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:31 - WARNING - No data for 2025-11-12 23:00:00-08:00 to 2025-12-13 23:00:00-08:00
#  67%|██████▋   | 8/12 [01:39<00:43, 10.84s/it]2026-04-14 21:23:31 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:23:31 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20251214T07:00-0000&enddatetime=20260114T07:00-0000
# Error: No data found for start date: 2025-11-12 23:00:00-08:00 and end date: 2025-12-13 23:00:00-08:00
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-11-12 23:00:00-0800', tz='US/Pacific'), 'market': <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>, 'locations': ['TH_NP15_GEN-APND', 'TH_SP15_GEN-APND', 'TH_ZP26_GEN-APND'], 'end': Timestamp('2025-12-13 23:00:00-0800', tz='US/Pacific')}
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:37 - WARNING - No data for 2025-12-13 23:00:00-08:00 to 2026-01-13 23:00:00-08:00
#  75%|███████▌  | 9/12 [01:45<00:27,  9.24s/it]2026-04-14 21:23:37 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:23:37 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20260114T07:00-0000&enddatetime=20260214T07:00-0000
# Error: No data found for start date: 2025-12-13 23:00:00-08:00 and end date: 2026-01-13 23:00:00-08:00
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-12-13 23:00:00-0800', tz='US/Pacific'), 'market': <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>, 'locations': ['TH_NP15_GEN-APND', 'TH_SP15_GEN-APND', 'TH_ZP26_GEN-APND'], 'end': Timestamp('2026-01-13 23:00:00-0800', tz='US/Pacific')}
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:43 - WARNING - No data for 2026-01-13 23:00:00-08:00 to 2026-02-13 23:00:00-08:00
#  83%|████████▎ | 10/12 [01:50<00:16,  8.19s/it]2026-04-14 21:23:43 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:23:43 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20260214T07:00-0000&enddatetime=20260317T07:00-0000
# Error: No data found for start date: 2026-01-13 23:00:00-08:00 and end date: 2026-02-13 23:00:00-08:00
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2026-01-13 23:00:00-0800', tz='US/Pacific'), 'market': <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>, 'locations': ['TH_NP15_GEN-APND', 'TH_SP15_GEN-APND', 'TH_ZP26_GEN-APND'], 'end': Timestamp('2026-02-13 23:00:00-0800', tz='US/Pacific')}
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:48 - DEBUG - Found 1 files: ['20260213_20260317_PRC_LMP_DAM_20260414_18_23_41_v12.csv']
# 2026-04-14 21:23:48 - DEBUG - Parsing file: 20260213_20260317_PRC_LMP_DAM_20260414_18_23_41_v12.csv
#  92%|█████████▏| 11/12 [02:01<00:08,  8.83s/it]2026-04-14 21:23:53 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:23:53 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&node=TH_NP15_GEN-APND,TH_SP15_GEN-APND,TH_ZP26_GEN-APND&startdatetime=20260317T07:00-0000&enddatetime=20260414T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:23:58 - DEBUG - Found 1 files: ['20260317_20260414_PRC_LMP_DAM_20260414_18_23_52_v12.csv']
# 2026-04-14 21:23:58 - DEBUG - Parsing file: 20260317_20260414_PRC_LMP_DAM_20260414_18_23_52_v12.csv
# 100%|██████████| 12/12 [02:10<00:00, 10.88s/it]
# Errors that occurred while getting data:
# [{'date': Timestamp('2025-11-12 23:00:00-0800', tz='US/Pacific'),
#   'end': Timestamp('2025-12-13 23:00:00-0800', tz='US/Pacific'),
#   'locations': ['TH_NP15_GEN-APND', 'TH_SP15_GEN-APND', 'TH_ZP26_GEN-APND'],
#   'market': <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>,
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-12-13 23:00:00-0800', tz='US/Pacific'),
#   'end': Timestamp('2026-01-13 23:00:00-0800', tz='US/Pacific'),
#   'locations': ['TH_NP15_GEN-APND', 'TH_SP15_GEN-APND', 'TH_ZP26_GEN-APND'],
#   'market': <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>,
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2026-01-13 23:00:00-0800', tz='US/Pacific'),
#   'end': Timestamp('2026-02-13 23:00:00-0800', tz='US/Pacific'),
#   'locations': ['TH_NP15_GEN-APND', 'TH_SP15_GEN-APND', 'TH_ZP26_GEN-APND'],
#   'market': <Markets.DAY_AHEAD_HOURLY: 'DAY_AHEAD_HOURLY'>,
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>}]

# %%
lmp_df.head()
# Out:
#                        Time            Interval Start  \
# 0 2025-04-10 00:00:00-07:00 2025-04-10 00:00:00-07:00
# 1 2025-04-10 00:00:00-07:00 2025-04-10 00:00:00-07:00
# 2 2025-04-10 00:00:00-07:00 2025-04-10 00:00:00-07:00
# 3 2025-04-10 01:00:00-07:00 2025-04-10 01:00:00-07:00
# 4 2025-04-10 01:00:00-07:00 2025-04-10 01:00:00-07:00
#
#                Interval End            Market          Location Location Type  \
# 0 2025-04-10 01:00:00-07:00  DAY_AHEAD_HOURLY  TH_NP15_GEN-APND   Trading Hub
# 1 2025-04-10 01:00:00-07:00  DAY_AHEAD_HOURLY  TH_SP15_GEN-APND   Trading Hub
# 2 2025-04-10 01:00:00-07:00  DAY_AHEAD_HOURLY  TH_ZP26_GEN-APND   Trading Hub
# 3 2025-04-10 02:00:00-07:00  DAY_AHEAD_HOURLY  TH_NP15_GEN-APND   Trading Hub
# 4 2025-04-10 02:00:00-07:00  DAY_AHEAD_HOURLY  TH_SP15_GEN-APND   Trading Hub
#
#         LMP    Energy  Congestion     Loss
# 0  36.89833  43.17463    -3.94919 -2.32711
# 1  43.32351  43.17463     0.94330 -0.79441
# 2  39.86061  43.17463    -1.48774 -1.82629
# 3  36.23791  42.53287    -4.05347 -2.24148
# 4  42.74047  42.53287     0.95193 -0.74433

# %% [markdown]
# ## Figure 1: Negative Instances of Negative Locational Marginal Pricing per Month

# %% [markdown]
# Observed a higher negative LMP in the Spring months, where high electric runoff and solar output align with low cooling or heating demand.

# %%
# Filter all negative locational merginal pricing
negative_lmps = lmp_df[lmp_df["LMP"] < 0].set_index("Time")

# Filter negative LPM by month by location
negative_per_month = (
    negative_lmps.groupby("Location").resample("MS")["LMP"].count().reset_index()
)

# Visualization
fig = px.bar(
    negative_per_month,
    x="Time",
    y="LMP",
    title="Negative LMPs per Month - CAISO",
    color="Location",
)
fig.update_yaxes(title="Number of Negative LMPs")
fig.show("svg", width=800, height=600)

# %% [markdown]
# ## Figure 2: Daily Average Locational Marginal Pricing (LMP)

# %% [markdown]
# We observed an tight cluster regional LMP, indicate a unconstrained movement of electricity across the North, Central, and South of California

# %%
# Mean of daily LMP:
daily_lmp = lmp_df.set_index("Time").groupby("Location").resample("1D")["LMP"].mean().reset_index()
fig = px.line(
    daily_lmp, 
    x="Time", 
    y="LMP", 
    title="DAILY LMP - CAISO", 
    color="Location"
)
fig.show("svg",width=800, height=600)

# %% [markdown]
# There was a huge missing data from the CAISO during the November 2025 and Febuary 2026 time frame. We can request access and assistant from the IT team or CAISO spoke-person.

# %%
daily_lmp.loc[daily_lmp["LMP"].isna()]
# Out:
#               Location                      Time  LMP
# 217   TH_NP15_GEN-APND 2025-11-13 00:00:00-08:00  NaN
# 218   TH_NP15_GEN-APND 2025-11-14 00:00:00-08:00  NaN
# 219   TH_NP15_GEN-APND 2025-11-15 00:00:00-08:00  NaN
# 220   TH_NP15_GEN-APND 2025-11-16 00:00:00-08:00  NaN
# 221   TH_NP15_GEN-APND 2025-11-17 00:00:00-08:00  NaN
# ...                ...                       ...  ...
# 1042  TH_ZP26_GEN-APND 2026-02-08 00:00:00-08:00  NaN
# 1043  TH_ZP26_GEN-APND 2026-02-09 00:00:00-08:00  NaN
# 1044  TH_ZP26_GEN-APND 2026-02-10 00:00:00-08:00  NaN
# 1045  TH_ZP26_GEN-APND 2026-02-11 00:00:00-08:00  NaN
# 1046  TH_ZP26_GEN-APND 2026-02-12 00:00:00-08:00  NaN
#
# [276 rows x 3 columns]

# %% [markdown]
# # Energy Curtailment

# %% [markdown]
# - Company can purposefully reduce output of renewable energy (wind, solar). Here, we can investigate the curtailment status

# %%
curtail_df = iso.get_curtailment(
    start="April 10, 2025", 
    end="today", 
    # save_to="curtailment/"
)
# Out:
#   0%|          | 1/370 [00:01<06:19,  1.03s/it]
# Error: Failed to fetch renewables report for 2025-04-10: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-10 00:00:00-0700', tz='US/Pacific')}
#   1%|          | 2/370 [00:01<04:59,  1.23it/s]
# Error: Failed to fetch renewables report for 2025-04-11: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-11 00:00:00-0700', tz='US/Pacific')}
#   1%|          | 3/370 [00:02<04:42,  1.30it/s]
# Error: Failed to fetch renewables report for 2025-04-12: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-12 00:00:00-0700', tz='US/Pacific')}
#   1%|          | 4/370 [00:03<04:25,  1.38it/s]
# Error: Failed to fetch renewables report for 2025-04-13: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-13 00:00:00-0700', tz='US/Pacific')}
#   1%|▏         | 5/370 [00:03<04:17,  1.42it/s]
# Error: Failed to fetch renewables report for 2025-04-14: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-14 00:00:00-0700', tz='US/Pacific')}
#   2%|▏         | 6/370 [00:04<04:09,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-04-15: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-15 00:00:00-0700', tz='US/Pacific')}
#   2%|▏         | 7/370 [00:05<04:06,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-04-16: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-16 00:00:00-0700', tz='US/Pacific')}
#   2%|▏         | 8/370 [00:05<04:05,  1.48it/s]
# Error: Failed to fetch renewables report for 2025-04-17: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-17 00:00:00-0700', tz='US/Pacific')}
#   2%|▏         | 9/370 [00:06<04:05,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-04-18: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-18 00:00:00-0700', tz='US/Pacific')}
#   3%|▎         | 10/370 [00:07<04:05,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-04-19: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-19 00:00:00-0700', tz='US/Pacific')}
#   3%|▎         | 11/370 [00:07<04:06,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-04-20: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-20 00:00:00-0700', tz='US/Pacific')}
#   3%|▎         | 12/370 [00:08<04:02,  1.48it/s]
# Error: Failed to fetch renewables report for 2025-04-21: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-21 00:00:00-0700', tz='US/Pacific')}
#   4%|▎         | 13/370 [00:09<04:06,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-04-22: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-22 00:00:00-0700', tz='US/Pacific')}
#   4%|▍         | 14/370 [00:09<04:05,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-04-23: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-23 00:00:00-0700', tz='US/Pacific')}
#   4%|▍         | 15/370 [00:10<04:03,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-04-24: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-24 00:00:00-0700', tz='US/Pacific')}
#   4%|▍         | 16/370 [00:11<04:05,  1.44it/s]
# Error: Failed to fetch renewables report for 2025-04-25: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-25 00:00:00-0700', tz='US/Pacific')}
#   5%|▍         | 17/370 [00:11<04:01,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-04-26: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-26 00:00:00-0700', tz='US/Pacific')}
#   5%|▍         | 18/370 [00:12<04:04,  1.44it/s]
# Error: Failed to fetch renewables report for 2025-04-27: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-27 00:00:00-0700', tz='US/Pacific')}
#   5%|▌         | 19/370 [00:13<04:02,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-04-28: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-28 00:00:00-0700', tz='US/Pacific')}
#   5%|▌         | 20/370 [00:14<04:02,  1.44it/s]
# Error: Failed to fetch renewables report for 2025-04-29: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-29 00:00:00-0700', tz='US/Pacific')}
#   6%|▌         | 21/370 [00:14<04:01,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-04-30: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-04-30 00:00:00-0700', tz='US/Pacific')}
#   6%|▌         | 22/370 [00:15<03:56,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-05-01: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-01 00:00:00-0700', tz='US/Pacific')}
#   6%|▌         | 23/370 [00:16<03:59,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-05-02: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-02 00:00:00-0700', tz='US/Pacific')}
#   6%|▋         | 24/370 [00:16<03:56,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-05-03: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-03 00:00:00-0700', tz='US/Pacific')}
#   7%|▋         | 25/370 [00:17<03:56,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-05-04: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-04 00:00:00-0700', tz='US/Pacific')}
#   7%|▋         | 26/370 [00:18<03:57,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-05-05: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-05 00:00:00-0700', tz='US/Pacific')}
#   7%|▋         | 27/370 [00:18<03:54,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-05-06: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-06 00:00:00-0700', tz='US/Pacific')}
#   8%|▊         | 28/370 [00:19<03:51,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-05-07: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-07 00:00:00-0700', tz='US/Pacific')}
#   8%|▊         | 29/370 [00:20<03:52,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-05-08: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-08 00:00:00-0700', tz='US/Pacific')}
#   8%|▊         | 30/370 [00:20<03:50,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-05-09: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-09 00:00:00-0700', tz='US/Pacific')}
#   8%|▊         | 31/370 [00:21<03:50,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-05-10: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-10 00:00:00-0700', tz='US/Pacific')}
#   9%|▊         | 32/370 [00:22<03:46,  1.49it/s]
# Error: Failed to fetch renewables report for 2025-05-11: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-11 00:00:00-0700', tz='US/Pacific')}
#   9%|▉         | 33/370 [00:22<03:46,  1.49it/s]
# Error: Failed to fetch renewables report for 2025-05-12: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-12 00:00:00-0700', tz='US/Pacific')}
#   9%|▉         | 34/370 [00:23<03:46,  1.49it/s]
# Error: Failed to fetch renewables report for 2025-05-13: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-13 00:00:00-0700', tz='US/Pacific')}
#   9%|▉         | 35/370 [00:24<03:48,  1.47it/s]
# Error: Failed to fetch renewables report for 2025-05-14: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-14 00:00:00-0700', tz='US/Pacific')}
#  10%|▉         | 36/370 [00:24<03:44,  1.49it/s]
# Error: Failed to fetch renewables report for 2025-05-15: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-15 00:00:00-0700', tz='US/Pacific')}
#  10%|█         | 37/370 [00:25<03:45,  1.48it/s]
# Error: Failed to fetch renewables report for 2025-05-16: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-16 00:00:00-0700', tz='US/Pacific')}
#  10%|█         | 38/370 [00:26<03:46,  1.46it/s]
# Error: Failed to fetch renewables report for 2025-05-17: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-17 00:00:00-0700', tz='US/Pacific')}
#  11%|█         | 39/370 [00:27<03:57,  1.39it/s]
# Error: Failed to fetch renewables report for 2025-05-18: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-18 00:00:00-0700', tz='US/Pacific')}
#  11%|█         | 40/370 [00:27<03:51,  1.42it/s]
# Error: Failed to fetch renewables report for 2025-05-19: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-19 00:00:00-0700', tz='US/Pacific')}
#  11%|█         | 41/370 [00:28<03:50,  1.43it/s]
# Error: Failed to fetch renewables report for 2025-05-20: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-20 00:00:00-0700', tz='US/Pacific')}
#  11%|█▏        | 42/370 [00:29<03:49,  1.43it/s]
# Error: Failed to fetch renewables report for 2025-05-21: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-21 00:00:00-0700', tz='US/Pacific')}
#  12%|█▏        | 43/370 [00:29<03:45,  1.45it/s]
# Error: Failed to fetch renewables report for 2025-05-22: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-22 00:00:00-0700', tz='US/Pacific')}
#  12%|█▏        | 44/370 [00:30<03:53,  1.40it/s]
# Error: Failed to fetch renewables report for 2025-05-23: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-23 00:00:00-0700', tz='US/Pacific')}
#  12%|█▏        | 45/370 [00:31<03:49,  1.41it/s]
# Error: Failed to fetch renewables report for 2025-05-24: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-24 00:00:00-0700', tz='US/Pacific')}
#  12%|█▏        | 46/370 [00:31<03:46,  1.43it/s]
# Error: Failed to fetch renewables report for 2025-05-25: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-25 00:00:00-0700', tz='US/Pacific')}
#  13%|█▎        | 47/370 [00:32<03:50,  1.40it/s]
# Error: Failed to fetch renewables report for 2025-05-26: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-26 00:00:00-0700', tz='US/Pacific')}
#  13%|█▎        | 48/370 [00:33<03:48,  1.41it/s]
# Error: Failed to fetch renewables report for 2025-05-27: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-27 00:00:00-0700', tz='US/Pacific')}
#  13%|█▎        | 49/370 [00:34<03:49,  1.40it/s]
# Error: Failed to fetch renewables report for 2025-05-28: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-28 00:00:00-0700', tz='US/Pacific')}
#  14%|█▎        | 50/370 [00:34<03:47,  1.41it/s]
# Error: Failed to fetch renewables report for 2025-05-29: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-29 00:00:00-0700', tz='US/Pacific')}
#  14%|█▍        | 51/370 [00:35<03:46,  1.41it/s]
# Error: Failed to fetch renewables report for 2025-05-30: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-30 00:00:00-0700', tz='US/Pacific')}
#  14%|█▍        | 52/370 [00:36<03:43,  1.42it/s]
# Error: Failed to fetch renewables report for 2025-05-31: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-05-31 00:00:00-0700', tz='US/Pacific')}
#  22%|██▏       | 82/370 [00:48<01:49,  2.62it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2025-06-30, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-06-30 00:00:00-0700', tz='US/Pacific')}
#  31%|███       | 113/370 [01:01<02:07,  2.01it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2025-07-31, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-07-31 00:00:00-0700', tz='US/Pacific')}
#  39%|███▉      | 144/370 [01:15<01:37,  2.32it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2025-08-31, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-08-31 00:00:00-0700', tz='US/Pacific')}
#  47%|████▋     | 174/370 [01:28<01:19,  2.46it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2025-09-30, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-09-30 00:00:00-0700', tz='US/Pacific')}
#  55%|█████▌    | 205/370 [01:41<01:03,  2.60it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2025-10-31, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-10-31 00:00:00-0700', tz='US/Pacific')}
#  64%|██████▎   | 235/370 [01:53<00:55,  2.44it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2025-11-30, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2025-11-30 00:00:00-0800', tz='US/Pacific')}
#  80%|████████  | 297/370 [02:19<00:28,  2.60it/s]
# Error: Renewables report column curt_monthly_ytd_perc_mwh returned 12 values for 2026-01-31, expected 13
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2026-01-31 00:00:00-0800', tz='US/Pacific')}
# 100%|██████████| 370/370 [02:49<00:00,  2.18it/s]
# Error: Failed to fetch renewables report for 2026-04-14: HTTP 404
# Args: {'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>, 'date': Timestamp('2026-04-14 00:00:00-0700', tz='US/Pacific')}
#
# Errors that occurred while getting data:
# [{'date': Timestamp('2025-04-10 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-11 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-12 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-13 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-14 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-15 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-16 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-17 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-18 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-19 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-20 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-21 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-22 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-23 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-24 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-25 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-26 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-27 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-28 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-29 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-04-30 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-01 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-02 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-03 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-04 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-05 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-06 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-07 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-08 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-09 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-10 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-11 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-12 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-13 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-14 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-15 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-16 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-17 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-18 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-19 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-20 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-21 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-22 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-23 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-24 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-25 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-26 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-27 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-28 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-29 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-30 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-05-31 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-06-30 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-07-31 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-08-31 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-09-30 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-10-31 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2025-11-30 00:00:00-0800', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2026-01-31 00:00:00-0800', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>},
#  {'date': Timestamp('2026-04-14 00:00:00-0700', tz='US/Pacific'),
#   'self': <gridstatus.caiso.caiso.CAISO object at 0x000002BCED24BB90>}]

# %%
curtail_df.head()
# Out:
#              Interval Start              Interval End     Curtailment Type  \
# 0 2025-06-01 00:00:00-07:00 2025-06-01 01:00:00-07:00             Economic
# 1 2025-06-01 00:00:00-07:00 2025-06-01 01:00:00-07:00             Economic
# 2 2025-06-01 00:00:00-07:00 2025-06-01 01:00:00-07:00             Economic
# 3 2025-06-01 00:00:00-07:00 2025-06-01 01:00:00-07:00             Economic
# 4 2025-06-01 00:00:00-07:00 2025-06-01 01:00:00-07:00  OperatorInstruction
#
#   Curtailment Reason Fuel Type  Curtailment MWH  Curtailment MW
# 0              Local     Solar         0.000000             0.0
# 1              Local      Wind         0.000045             0.0
# 2             System     Solar         0.000000             0.0
# 3             System      Wind         0.000066             0.0
# 4              Local     Solar         0.000000             0.0

# %%
curtail_df.columns = curtail_df.columns.str.strip()

curtail_df["Type"] = (
    curtail_df["Curtailment Reason"].str.lower().str.capitalize()
    + " "
    + curtail_df["Fuel Type"]
    + " Curtailment (MWh)"
)
curtailment = curtail_df.pivot_table(
    values="Curtailment MWH",
    index="Interval Start",
    columns="Type",
    # sum to account for 'Economic' and 'SelfSchCut' reasons
    aggfunc="sum",
).fillna(0)

curtailment["Total Solar Curtailment (MWh)"] = (
    curtailment["Local Solar Curtailment (MWh)"]
    + curtailment["System Solar Curtailment (MWh)"]
)
curtailment["Total Wind Curtailment (MWh)"] = (
    curtailment["Local Wind Curtailment (MWh)"]
    + curtailment["System Wind Curtailment (MWh)"]
)
curtailment["Total Curtailment (MWh)"] = (
    curtailment["Total Solar Curtailment (MWh)"]
    + curtailment["Total Wind Curtailment (MWh)"]
)
curtailment.columns.name = None
curtailment = curtailment.resample("1h").sum()

curtailment.head()
# Out:
#                            Local Solar Curtailment (MWh)  \
# Interval Start
# 2025-06-01 00:00:00-07:00                            0.0
# 2025-06-01 01:00:00-07:00                            0.0
# 2025-06-01 02:00:00-07:00                            0.0
# 2025-06-01 03:00:00-07:00                            0.0
# 2025-06-01 04:00:00-07:00                            0.0
#
#                            Local Wind Curtailment (MWh)  \
# Interval Start
# 2025-06-01 00:00:00-07:00                      0.000045
# 2025-06-01 01:00:00-07:00                      0.000010
# 2025-06-01 02:00:00-07:00                      0.000047
# 2025-06-01 03:00:00-07:00                      0.000023
# 2025-06-01 04:00:00-07:00                      0.000073
#
#                            System Solar Curtailment (MWh)  \
# Interval Start
# 2025-06-01 00:00:00-07:00                             0.0
# 2025-06-01 01:00:00-07:00                             0.0
# 2025-06-01 02:00:00-07:00                             0.0
# 2025-06-01 03:00:00-07:00                             0.0
# 2025-06-01 04:00:00-07:00                             0.0
#
#                            System Wind Curtailment (MWh)  \
# Interval Start
# 2025-06-01 00:00:00-07:00                       0.000066
# 2025-06-01 01:00:00-07:00                       0.000104
# 2025-06-01 02:00:00-07:00                       0.000063
# 2025-06-01 03:00:00-07:00                       0.000080
# 2025-06-01 04:00:00-07:00                       0.000024
#
#                            Total Solar Curtailment (MWh)  \
# Interval Start
# 2025-06-01 00:00:00-07:00                            0.0
# 2025-06-01 01:00:00-07:00                            0.0
# 2025-06-01 02:00:00-07:00                            0.0
# 2025-06-01 03:00:00-07:00                            0.0
# 2025-06-01 04:00:00-07:00                            0.0
#
#                            Total Wind Curtailment (MWh)  \
# Interval Start
# 2025-06-01 00:00:00-07:00                      0.000111
# 2025-06-01 01:00:00-07:00                      0.000114
# 2025-06-01 02:00:00-07:00                      0.000110
# 2025-06-01 03:00:00-07:00                      0.000104
# 2025-06-01 04:00:00-07:00                      0.000097
#
#                            Total Curtailment (MWh)
# Interval Start
# 2025-06-01 00:00:00-07:00                 0.000111
# 2025-06-01 01:00:00-07:00                 0.000114
# 2025-06-01 02:00:00-07:00                 0.000110
# 2025-06-01 03:00:00-07:00                 0.000104
# 2025-06-01 04:00:00-07:00                 0.000097

# %% [markdown]
# ## Figure 3: Cumalative Curtailment in 2025 and 2026

# %%
# Create sum table
daily_curtailment = curtailment.resample("1D").sum()
cumulative_curtailment = (
    daily_curtailment.groupby(daily_curtailment.index.year)["Total Curtailment (MWh)"]
    .cumsum()
    .reset_index()
)

# add year and month 
cumulative_curtailment["Year"] = cumulative_curtailment["Interval Start"].dt.year
cumulative_curtailment["Day of Year"] = cumulative_curtailment[
    "Interval Start"
].dt.strftime("%b %d")

# plot all years together
fig = px.line(
    cumulative_curtailment,
    y="Total Curtailment (MWh)",
    x="Day of Year",
    title="Cumalative Curtailment (MWh)",
    color="Year",
)

fig.show("svg", width=800, height=600)

# %% [markdown]
# ## Figure 4: Monthly Curtailment

# %% [markdown]
# We observed a high curtailment during the Spring time, this is consistent with reduction in demand of heating or cooling use during the Spring time.

# %%
monthly = curtailment.resample("ME").sum()
monthly["Month"] = monthly.index.month
monthly["Year"] = monthly.index.year

# plot
fig = px.bar(
    monthly,
    x=monthly.index,
    y=["Total Solar Curtailment (MWh)", "Total Wind Curtailment (MWh)"],
    title="Monthly Solar and Wind Curtailment in CAISO (MWh)",
)

# legend upper left corner
fig.update_layout(
    legend=dict(
        orientation="h", yanchor="bottom", y=1.02, xanchor="left", x=0, title_text=None
    )
)
fig.update_yaxes(title_text="Curtailment (MWh)")
fig.show("svg", width=800, height=600)

# %% [markdown]
# # List all data set for download

# %%
iso.list_oasis_datasets()
# Out:
# Dataset: transmission_interface_usage
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | DAM       | DAM, HASP, RRPD   |
# +---------------+-----------+-------------------+
# | ti_id         | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | ti_direction  | ALL       | ALL, E, I         |
# +---------------+-----------+-------------------+
#
#
# Dataset: schedule_by_tie
# +-------------+------------------------+-------------------------------------------------------------------------------------------------+
# | Parameter   | Default                | Possible Values                                                                                 |
# +=============+========================+=================================================================================================+
# | groupid     | RTD_ENE_SCH_BY_TIE_GRP | RTD_ENE_SCH_BY_TIE_GRP, DAM_ENE_SCH_BY_TIE_GRP, RUC_ENE_SCH_BY_TIE_GRP, RTPD_ENE_SCH_BY_TIE_GRP |
# +-------------+------------------------+-------------------------------------------------------------------------------------------------+
#
#
# Dataset: as_requirements
# +---------------+-----------+-------------------------------------------------------------------------+
# | Parameter     | Default   | Possible Values                                                         |
# +===============+===========+=========================================================================+
# | market_run_id | DAM       | DAM, HASP, RTM, 2DA                                                     |
# +---------------+-----------+-------------------------------------------------------------------------+
# | anc_type      | ALL       | ALL, NR, RD, RU, SR, RMD, RMU                                           |
# +---------------+-----------+-------------------------------------------------------------------------+
# | anc_region    | ALL       | ALL, AS_CAISO, AS_CAISO_EXP, AS_NP26, AS_NP26_EXP, AS_SP26, AS_SP26_EXP |
# +---------------+-----------+-------------------------------------------------------------------------+
#
#
# Dataset: as_clearing_prices
# +---------------+-----------+-------------------------------------------------------------------------+
# | Parameter     | Default   | Possible Values                                                         |
# +===============+===========+=========================================================================+
# | market_run_id | DAM       | DAM, HASP                                                               |
# +---------------+-----------+-------------------------------------------------------------------------+
# | anc_type      | ALL       | ALL, NR, RD, RMD, RMU, RU, SR                                           |
# +---------------+-----------+-------------------------------------------------------------------------+
# | anc_region    | ALL       | ALL, AS_CAISO, AS_SP26_EXP, AS_SP26, AS_CAISO_EXP, AS_NP26_EXP, AS_NP26 |
# +---------------+-----------+-------------------------------------------------------------------------+
#
#
# Dataset: fuel_prices
# +----------------+-----------+-------------------+
# | Parameter      | Default   | Possible Values   |
# +================+===========+===================+
# | fuel_region_id | ALL       | N/A               |
# +----------------+-----------+-------------------+
#
#
# Dataset: ghg_allowance
#     No parameters
#
#
# Dataset: renewables
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | ACTUAL    | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: renewables_forecast_dam
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | DAM       | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: renewables_forecast_hasp
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | HASP      | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: renewables_forecast_rtd
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | RTD       | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: renewables_forecast_rtpd
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | RTPD      | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: pnode_map
# +-------------+-----------+-------------------+
# | Parameter   | Default   | Possible Values   |
# +=============+===========+===================+
# | pnode_id    | ALL       | N/A               |
# +-------------+-----------+-------------------+
#
#
# Dataset: lmp_day_ahead_hourly
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | DAM       | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+
#
#
# Dataset: lmp_real_time_5_min
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | RTM       | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+
#
#
# Dataset: lmp_real_time_15_min
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | RTPD      | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+
#
#
# Dataset: lmp_scheduling_point_tie_combination_5_min
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | RTD       | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+
#
#
# Dataset: lmp_scheduling_point_tie_combination_15_min
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | RTPD      | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+
#
#
# Dataset: lmp_scheduling_point_tie_combination_hourly
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | DAM       | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+
#
#
# Dataset: lmp_hasp_15_min
# +-------------+-----------+------------------------+
# | Parameter   | Default   | Possible Values        |
# +=============+===========+========================+
# | node        |           | N/A                    |
# +-------------+-----------+------------------------+
# | grp_type    |           | None, ALL, ALL_APNODES |
# +-------------+-----------+------------------------+
#
#
# Dataset: demand_forecast
# +----------------+-----------+----------------------------+
# | Parameter      | Default   | Possible Values            |
# +================+===========+============================+
# | market_run_id  | 7DA       | 7DA, 2DA, DAM, ACTUAL, RTM |
# +----------------+-----------+----------------------------+
# | execution_type |           | None, RTPD, RTD            |
# +----------------+-----------+----------------------------+
#
#
# Dataset: as_results
# +---------------+-----------+-------------------------------------------------------------------------+
# | Parameter     | Default   | Possible Values                                                         |
# +===============+===========+=========================================================================+
# | market_run_id | DAM       | DAM, HASP, RTM                                                          |
# +---------------+-----------+-------------------------------------------------------------------------+
# | anc_type      | ALL       | ALL, NR, RD, RU, SR, RMD, RMU                                           |
# +---------------+-----------+-------------------------------------------------------------------------+
# | anc_region    | ALL       | ALL, AS_CAISO, AS_CAISO_EXP, AS_NP26, AS_NP26_EXP, AS_SP26, AS_SP26_EXP |
# +---------------+-----------+-------------------------------------------------------------------------+
#
#
# Dataset: excess_btm_production
#     No parameters
#
#
# Dataset: public_bids
# +-------------+-------------+--------------------------+
# | Parameter   | Default     | Possible Values          |
# +=============+=============+==========================+
# | groupid     | PUB_DAM_GRP | PUB_DAM_GRP, PUB_RTM_GRP |
# +-------------+-------------+--------------------------+
#
#
# Dataset: tie_flows_real_time
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | baa_grp_id    | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | market_run_id | RTD       | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: tie_flows_real_time_15_min
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | baa_grp_id    | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | market_run_id | RTPD      | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: tie_schedule_day_ahead_hourly
# +---------------+------------------------+------------------------+
# | Parameter     | Default                | Possible Values        |
# +===============+========================+========================+
# | groupid       | DAM_ENE_SCH_BY_TIE_GRP | DAM_ENE_SCH_BY_TIE_GRP |
# +---------------+------------------------+------------------------+
# | market_run_id | DAM                    | N/A                    |
# +---------------+------------------------+------------------------+
#
#
# Dataset: nomogram_branch_shadow_prices
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | DAM       | DAM, HASP, RTM    |
# +---------------+-----------+-------------------+
#
#
# Dataset: interval_nomogram_branch_shadow_prices
#     No parameters
#
#
# Dataset: interval_intertie_constraint_shadow_prices
#     No parameters
#
#
# Dataset: system_load_and_resource_schedules_day_ahead
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | DAM       | N/A               |
# +---------------+-----------+-------------------+
# | tac_zone_name | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | schedule      | ALL       | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: system_load_and_resource_schedules_hasp
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | HASP      | N/A               |
# +---------------+-----------+-------------------+
# | tac_zone_name | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | schedule      | ALL       | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: system_load_and_resource_schedules_real_time_5_min
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | RTM       | N/A               |
# +---------------+-----------+-------------------+
# | tac_zone_name | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | schedule      | ALL       | N/A               |
# +---------------+-----------+-------------------+
#
#
# Dataset: system_load_and_resource_schedules_ruc
# +---------------+-----------+-------------------+
# | Parameter     | Default   | Possible Values   |
# +===============+===========+===================+
# | market_run_id | RUC       | N/A               |
# +---------------+-----------+-------------------+
# | tac_zone_name | ALL       | N/A               |
# +---------------+-----------+-------------------+
# | schedule      | ALL       | N/A               |
# +---------------+-----------+-------------------+

# %%
iso.list_oasis_datasets("lmp_day_ahead_hourly")
# Out:
# Dataset: lmp_day_ahead_hourly
# +---------------+-----------+------------------------+
# | Parameter     | Default   | Possible Values        |
# +===============+===========+========================+
# | market_run_id | DAM       | N/A                    |
# +---------------+-----------+------------------------+
# | node          |           | N/A                    |
# +---------------+-----------+------------------------+
# | grp_type      |           | None, ALL, ALL_APNODES |
# +---------------+-----------+------------------------+

# %%
df = iso.get_oasis_dataset(
    dataset="lmp_day_ahead_hourly",
    params={
        "market_run_id": "DAM",
    },
    date="April 10, 2026",
)
df.head()
# Out:
# 2026-04-14 21:27:05 - DEBUG - Dataset config: {'query': {'path': 'SingleZip', 'resultformat': 6, 'queryname': 'PRC_LMP', 'version': 12}, 'params': {'market_run_id': 'DAM', 'node': None, 'grp_type': [None, 'ALL', 'ALL_APNODES']}}
# 2026-04-14 21:27:05 - INFO - Fetching URL: http://oasis.caiso.com/oasisapi/SingleZip?resultformat=6&queryname=PRC_LMP&version=12&market_run_id=DAM&startdatetime=20260410T07:00-0000&enddatetime=20260411T07:00-0000
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\delta\miniconda3\envs\grid_env_py311\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'oasis.caiso.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-04-14 21:27:20 - DEBUG - Found 5 files: ['20260410_20260410_PRC_LMP_DAM_LMP_v12.csv', '20260410_20260410_PRC_LMP_DAM_MCE_v12.csv', '20260410_20260410_PRC_LMP_DAM_MCC_v12.csv', '20260410_20260410_PRC_LMP_DAM_MCL_v12.csv', '20260410_20260410_PRC_LMP_DAM_MGHG_v12.csv']
# 2026-04-14 21:27:20 - DEBUG - Parsing file: 20260410_20260410_PRC_LMP_DAM_LMP_v12.csv
# 2026-04-14 21:27:21 - DEBUG - Parsing file: 20260410_20260410_PRC_LMP_DAM_MCE_v12.csv
# 2026-04-14 21:27:22 - DEBUG - Parsing file: 20260410_20260410_PRC_LMP_DAM_MCC_v12.csv
# 2026-04-14 21:27:23 - DEBUG - Parsing file: 20260410_20260410_PRC_LMP_DAM_MCL_v12.csv
# 2026-04-14 21:27:23 - DEBUG - Parsing file: 20260410_20260410_PRC_LMP_DAM_MGHG_v12.csv
#            INTERVALSTARTTIME_GMT       INTERVALENDTIME_GMT      OPR_DT  \
# 163184 2026-04-10 07:00:00+00:00 2026-04-10 08:00:00+00:00  2026-04-10
# 157306 2026-04-10 07:00:00+00:00 2026-04-10 08:00:00+00:00  2026-04-10
# 194839 2026-04-10 07:00:00+00:00 2026-04-10 08:00:00+00:00  2026-04-10
# 49362  2026-04-10 07:00:00+00:00 2026-04-10 08:00:00+00:00  2026-04-10
# 194878 2026-04-10 07:00:00+00:00 2026-04-10 08:00:00+00:00  2026-04-10
#
#         OPR_HR  OPR_INTERVAL            NODE_ID_XML                NODE_ID  \
# 163184       1             0          HYML_LNODEYML          HYML_LNODEYML
# 157306       1             0  HOL_1_HAFBS1_SLRGNODE  HOL_1_HAFBS1_SLRGNODE
# 194839       1             0        LONETREE_2_N014        LONETREE_2_N014
# 49362        1             0      CASHI_SR_LNODELD5      CASHI_SR_LNODELD5
# 194878       1             0      LONE_MTN_LNODEK1L      LONE_MTN_LNODEK1L
#
#                          NODE MARKET_RUN_ID LMP_TYPE XML_DATA_ITEM  \
# 163184          HYML_LNODEYML           DAM      LMP       LMP_PRC
# 157306  HOL_1_HAFBS1_SLRGNODE           DAM     MGHG   LMP_GHG_PRC
# 194839        LONETREE_2_N014           DAM      MCC  LMP_CONG_PRC
# 49362       CASHI_SR_LNODELD5           DAM      MCE   LMP_ENE_PRC
# 194878      LONE_MTN_LNODEK1L           DAM      MCC  LMP_CONG_PRC
#
#                 PNODE_RESMRID GRP_TYPE  POS        MW  GROUP
# 163184          HYML_LNODEYML      ALL    1  32.98967   6800
# 157306  HOL_1_HAFBS1_SLRGNODE      ALL    1   0.00000   6555
# 194839        LONETREE_2_N014      ALL    1   0.00000   8119
# 49362       CASHI_SR_LNODELD5      ALL    1  34.42520   2057
# 194878      LONE_MTN_LNODEK1L      ALL    1   0.00000   8120

# %% [markdown]
# # -- End
